# %%
# Importing our libraries/modules:
import pandas as pd
import scipy
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reading our cleaned dataset '2015' and printing for preview:
states_2015 = pd.read_csv('../Output/2015_cleaned_state.csv')
states_2015.head()
# Out:
#         State  TotalPop       Men     Women  Hispanic     White    Black  \
# 0     Alabama   4830620   2341093   2489527    193159   3204658  1270556
# 1      Alaska    733375    384160    349215     47860    457438    23611
# 2     Arizona   6641928   3299088   3342840   2015055   3751927   263011
# 3    Arkansas   2958208   1451913   1506295    203216   2177095   456609
# 4  California  38421464  19087135  19334329  14746502  14878698  2157932
#
#    Native    Asian  Pacific  ...  OtherTrans  WorkatHome  MeanCommute  \
# 0   22007    59324     1089  ...       20994       56260           25
# 1   98381    42323     8638  ...       19750       16083           10
# 2  265835   193799    11587  ...       77252      156279           21
# 3   16531    39968     6628  ...       15580       40259           22
# 4  144676  5192680   133245  ...      437377      917120           24
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Poverty  ChildPoverty  \
# 0      1583312      329430        105863        3715   910480       1318475
# 1       240061       88175         22190         634    74612         99617
# 2      2230882      412325        166404        5502  1210351       1724490
# 3       969630      205337         78614        2406   571519        821223
# 4     13403787     2381720       1434085       34099  6260461       8451647
#
#    Unemployment
# 0        454437
# 1         61930
# 2        603924
# 3        231142
# 4       3845611
#
# [5 rows x 35 columns]

# %%
# Building a dataframe to find the types that makes up the states workforce based on 2015:
workforce_2015 = states_2015[['State', 'TotalPop', 'Professional', 'Service', 'Office', 'Construction', 'Production']]
workforce_2015
# Out:
#                    State  TotalPop  Professional  Service   Office  \
# 0                Alabama   4830620        673255   339029   488076
# 1                 Alaska    733375        127176    61309    79684
# 2                Arizona   6641928        987208   559381   738734
# 3               Arkansas   2958208        401480   214384   299994
# 4             California  38421464       6430885  3239609  4090430
# 5               Colorado   5278906       1061308   457811   625309
# 6            Connecticut   3593222        742779   316970   419154
# 7               Delaware    926454        166436    80269   104822
# 8   District of Columbia    647484        205729    51347    58779
# 9                Florida  19645772       2908802  1755754  2334986
# 10               Georgia  10006693       1576974   743126  1087771
# 11                Hawaii   1406299        222251   148831   161802
# 12                 Idaho   1616547        239807   128959   172304
# 13              Illinois  12873761       2241669  1058597  1492891
# 14               Indiana   6568645        983253   517128   708312
# 15                  Iowa   3093526        542677   261699   367073
# 16                Kansas   2892987        515137   234296   321964
# 17              Kentucky   4397353        622798   318532   451845
# 18             Louisiana   4625253        653944   386863   481868
# 19                 Maine   1329100        229665   120079   155320
# 20              Maryland   5930538       1326995   511425   671770
# 21         Massachusetts   6705586       1510658   602200   767213
# 22              Michigan   9900571       1525072   795694  1036991
# 23             Minnesota   5419171       1115425   468968   652821
# 24           Mississippi   2988081        374648   214189   284204
# 25              Missouri   6045448        987899   506636   694121
# 26               Montana   1014699        174485    92863   110193
# 27              Nebraska   1869365        345074   161543   232576
# 28                Nevada   2798636        351080   352272   329388
# 29         New Hampshire   1324201        278289   110069   169210
# 30            New Jersey   8904413       1751353   716263  1059068
# 31            New Mexico   2084117        309908   182669   203699
# 32              New York  19673174       3627737  1878790  2197691
# 33        North Carolina   9845333       1583333   772047  1023569
# 34          North Dakota    721640        135687    65637    87261
# 35                  Ohio  11575977       1880858   944212  1282518
# 36              Oklahoma   3849733        571927   303424   415941
# 37                Oregon   3939233        662194   333724   419756
# 38          Pennsylvania  12779559       2202706  1055708  1439429
# 39           Puerto Rico   3583073        339188   219077   294461
# 40          Rhode Island   1053661        191143   104527   126490
# 41        South Carolina   4777576        686578   379484   514900
# 42          South Dakota    843190        150110    74615   103205
# 43             Tennessee   6499615        976072   490615   718744
# 44                 Texas  26538614       4247210  2138320  2950629
# 45                  Utah   2903379        492596   208883   350088
# 46               Vermont    626604        132070    56737    69865
# 47              Virginia   8256630       1703507   675311   899393
# 48            Washington   6985464       1270889   571420   735698
# 49         West Virginia   1851420        241502   141352   181571
# 50             Wisconsin   5742117        996025   490473   664843
# 51               Wyoming    579679         95680    52165    62529
#
#     Construction  Production
# 0         200091      321588
# 1          43898       39012
# 2         258624      271425
# 3         134389      205659
# 4        1583555     1904369
# 5         246089      234204
# 6         132019      170950
# 7          36896       45653
# 8           9796       12499
# 9         768877      772409
# 10        401066      578193
# 11         63879       56508
# 12         85315       89402
# 13        444843      847902
# 14        268316      562396
# 15        147227      254821
# 16        139018      190608
# 17        180850      317292
# 18        244512      248674
# 19         69702       73897
# 20        233476      233006
# 21        236150      299195
# 22        339169      675575
# 23        223399      366464
# 24        133551      197213
# 25        246628      372219
# 26         61895       45944
# 27         98579      130148
# 28        110653      123876
# 29         63105       78028
# 30        309019      445768
# 31         99233       80744
# 32        673624      874084
# 33        410376      582950
# 34         50976       48034
# 35        412560      845571
# 36        200444      227125
# 37        158850      215329
# 38        495203      807659
# 39        102026      108367
# 40         37476       58523
# 41        189985      304510
# 42         47329       55458
# 43        255547      447421
# 44       1315112     1443588
# 45        118671      167108
# 46         33059       35033
# 47        334434      378596
# 48        313470      368273
# 49         89609       97065
# 50        245733      485798
# 51         47146       36422

# %%
# Creating a 'Stacked Bar Graph' for 2015 to display the ratios of workforce types:
x = workforce_2015['State']
y0 = workforce_2015['Professional']
y1 = workforce_2015['Service']
y2 = workforce_2015['Office']
y3 = workforce_2015['Construction']
y4 = workforce_2015['Production']

plt.figure(figsize=(15, 15))

p1 = plt.bar(x,y0, color='blue', label='Professional')
p2 = plt.bar(x,y2, color='yellow', label='Office')
p3 = plt.bar(x,y1, color='red', label='Service')
p4 = plt.bar(x,y4, color='green', label='Production')
p5 = plt.bar(x,y3, color='orange', label='Construction')

plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(y0)+100000)

plt.title("Workforce Types based on 2015 Total State Population")
plt.xlabel("U.S. States, DC, & Puerto Rico")
plt.ylabel("Total Population per State")
plt.legend(loc='best')

tick_locations = [value for value in x]
plt.xticks(tick_locations, rotation=90)

plt.savefig('Images/Fig1.png')
plt.show()

# %%
# Reading our cleaned dataset '2017' and printing for preview:
states_2017 = pd.read_csv('../Output/2017_cleaned_state.csv')
states_2017.head()
# Out:
#         State  TotalPop       Men     Women  Hispanic     White    Black  \
# 0     Alabama   4850771   2350806   2499965    198385   3197877  1280323
# 1      Alaska    738565    386319    352246     50301    454526    22330
# 2     Arizona   6809946   3385055   3424891   2103443   3785517   277136
# 3    Arkansas   2977944   1461651   1516293    213373   2174088   457312
# 4  California  38982847  19366579  19616268  15106298  14778217  2162560
#
#    Native    Asian  Pacific  ...  OtherTrans  WorkatHome  MeanCommute  \
# 0   22671    61659      926  ...       20721       63042           25
# 1  101633    44754     8646  ...       18812       15742           10
# 2  264780   208375    11879  ...       76986      173850           21
# 3   17022    42027     6770  ...       15631       41029           22
# 4  138859  5430051   135141  ...      458329      998319           25
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Poverty  ChildPoverty  \
# 0      1624514      320525        106343        3905   871849       1258459
# 1       241717       89250         22129         709    75144         99936
# 2      2357823      411571        178504        3943  1154434       1633853
# 3       997809      198806         77564        2215   541298        769388
# 4     14065256     2429116       1465746       33582  5893442       7890893
#
#    Unemployment
# 0        366302
# 1         59123
# 2        490949
# 3        189390
# 4       3028451
#
# [5 rows x 35 columns]

# %%
# Building a dataframe to find the types that makes up the states workforce based on 2017:
workforce_2017 = states_2017[['State', 'TotalPop', 'Professional', 'Service', 'Office', 'Construction', 'Production']]
workforce_2017
# Out:
#                    State  TotalPop  Professional  Service   Office  \
# 0                Alabama   4850771        700402   341535   486835
# 1                 Alaska    738565        130009    61186    80447
# 2                Arizona   6809946       1054297   580215   766360
# 3               Arkansas   2977944        421471   216663   299241
# 4             California  38982847       6851451  3359128  4157519
# 5               Colorado   5436519       1138298   476996   636687
# 6            Connecticut   3594478        767849   321701   413073
# 7               Delaware    943732        175710    78844   103488
# 8   District of Columbia    672391        220701    54728    59736
# 9                Florida  20278447       3121774  1832638  2407538
# 10               Georgia  10201635       1687384   768146  1118149
# 11                Hawaii   1421658        229478   154050   167169
# 12                 Idaho   1657375        256451   133568   175656
# 13              Illinois  12854526       2320896  1065994  1480996
# 14               Indiana   6614418       1037584   521859   709542
# 15                  Iowa   3118102        564542   263531   363179
# 16                Kansas   2903820        538254   234439   318350
# 17              Kentucky   4424376        645565   323306   456972
# 18             Louisiana   4663461        672426   389619   481132
# 19                 Maine   1330158        241382   120516   152846
# 20              Maryland   5996079       1376447   521631   664205
# 21         Massachusetts   6789319       1597277   622939   761643
# 22              Michigan   9925568       1612913   803361  1039668
# 23             Minnesota   5490726       1164972   478709   654572
# 24           Mississippi   2986220        384863   218484   283842
# 25              Missouri   6075300       1029423   505886   694957
# 26               Montana   1029862        181666    94410   111093
# 27              Nebraska   1893921        363016   161860   231408
# 28                Nevada   2887725        381097   362083   343400
# 29         New Hampshire   1331848        287729   113881   169868
# 30            New Jersey   8960161       1829639   727347  1056140
# 31            New Mexico   2084828        313785   183041   205082
# 32              New York  19798228       3804355  1906426  2195563
# 33        North Carolina  10052564       1686509   797327  1054985
# 34          North Dakota    745475        144321    68271    87328
# 35                  Ohio  11609756       1975082   952013  1276866
# 36              Oklahoma   3896251        594926   304866   416078
# 37                Oregon   4025127        719098   344219   432224
# 38          Pennsylvania  12790505       2297091  1063449  1420484
# 39           Puerto Rico   3468963        336642   215230   287259
# 40          Rhode Island   1056138        200223   103685   124159
# 41        South Carolina   4893444        734559   395325   531299
# 42          South Dakota    855444        154251    74026   103950
# 43             Tennessee   6597381       1029450   509265   725240
# 44                 Texas  27419612       4551411  2221673  3038291
# 45                  Utah   2993941        532564   217655   363218
# 46               Vermont    624636        133215    56885    69534
# 47              Virginia   8365952       1768368   686447   900689
# 48            Washington   7169967       1378040   579432   745805
# 49         West Virginia   1836843        245011   144458   176496
# 50             Wisconsin   5763217       1043488   494850   662970
# 51               Wyoming    583200         98537    52277    60885
#
#     Construction  Production
# 0         197968      328261
# 1          43609       38717
# 2         269572      285536
# 3         133648      205610
# 4        1630886     1988512
# 5         257842      249771
# 6         132934      169663
# 7          37397       46257
# 8           9657       12877
# 9         829093      826953
# 10        418566      613707
# 11         63817       57229
# 12         88269       94395
# 13        447446      863694
# 14        274650      580355
# 15        151511      256943
# 16        137171      191672
# 17        178876      333142
# 18        238007      249756
# 19         70195       73750
# 20        236398      242062
# 21        238416      305222
# 22        356012      712432
# 23        231692      373450
# 24        132340      202237
# 25        250501      386400
# 26         62505       48257
# 27         98373      132629
# 28        117126      137338
# 29         62240       79544
# 30        312681      460835
# 31         96914       80363
# 32        683551      881042
# 33        422605      609312
# 34         49850       50512
# 35        414087      870513
# 36        199522      231248
# 37        167151      223197
# 38        498621      815863
# 39         96538      104426
# 40         39123       58933
# 41        197606      321811
# 42         49147       56710
# 43        264278      468092
# 44       1371775     1507889
# 45        123626      175740
# 46         32712       34840
# 47        341263      387719
# 48        328044      385468
# 49         84503       96365
# 50        249117      488935
# 51         45264       36611

# %%
# Creating a 'Stacked Bar Graph' for 2017 to display the ratios of workforce types:
x = workforce_2017['State']
y0 = workforce_2017['Professional']
y1 = workforce_2017['Service']
y2 = workforce_2017['Office']
y3 = workforce_2017['Construction']
y4 = workforce_2017['Production']

plt.figure(figsize=(15, 15))

p1 = plt.bar(x,y0, color='blue', label='Professional')
p2 = plt.bar(x,y2, color='yellow', label='Office')
p3 = plt.bar(x,y1, color='red', label='Service')
p4 = plt.bar(x,y4, color='green', label='Production')
p5 = plt.bar(x,y3, color='orange', label='Construction')

plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(y0)+100000)

plt.title("Workforce Types based on 2017 Total State Population")
plt.xlabel("U.S. States, DC, & Puerto Rico")
plt.ylabel("Total Population per State")
plt.legend(loc='best')

tick_locations = [value for value in x]
plt.xticks(tick_locations, rotation=90)

plt.savefig('Images/Fig2.png')
plt.show()

# %% [markdown]
# #### The stacked bar graphs for 2015 and 2017 tells us a lot about the US workforce across the many states. First of all, there is hardly, if any, change from the 2015 and 2017 graph. For instance, it makes sense that the most populated states have more service workers. Another example, the states with the most production comes from Illinois, Indiana, Michigan, Ohio, and Pennsylvania. However, out of all the workforce types production is one of the smaller workforces across the entire country. Similarly, the office workers are minimal in several of the small states in our country (i.e., Alaska, Delaware, Hawaii, Maine, Montana, Vermont, and Wyoming).

# %%
# Building a dataframe to find the workforce sectors that make-up the states based on 2015:
sectors_2015 = states_2015[['State', 'TotalPop', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork']]
sectors_2015
# Out:
#                    State  TotalPop  PrivateWork  PublicWork  SelfEmployed  \
# 0                Alabama   4830620      1583312      329430        105863
# 1                 Alaska    733375       240061       88175         22190
# 2                Arizona   6641928      2230882      412325        166404
# 3               Arkansas   2958208       969630      205337         78614
# 4             California  38421464     13403787     2381720       1434085
# 5               Colorado   5278906      2086203      365801        167714
# 6            Connecticut   3593222      1429343      235296        112637
# 7               Delaware    926454       353077       63124         17027
# 8   District of Columbia    647484       236470       85805         14863
# 9                Florida  19645772      6957820     1067082        503058
# 10               Georgia  10006693      3472207      666033        241594
# 11                Hawaii   1406299       471804      134533         45177
# 12                 Idaho   1616547       546102      113154         54715
# 13              Illinois  12873761      5037492      756997        284045
# 14               Indiana   6568645      2559413      334074        140438
# 15                  Iowa   3093526      1254487      213153        102312
# 16                Kansas   2892987      1090690      222371         85400
# 17              Kentucky   4397353      1499268      286193        102647
# 18             Louisiana   4625253      1589480      312710        111087
# 19                 Maine   1329100       499949       91290         56693
# 20              Maryland   5930538      2167820      663202        141861
# 21         Massachusetts   6705586      2780637      424503        206933
# 22              Michigan   9900571      3659940      486222        220313
# 23             Minnesota   5419171      2327030      336102        159277
# 24           Mississippi   2988081       913680      222777         65646
# 25              Missouri   6045448      2284927      357610        159642
# 26               Montana   1014699       350657       87842         44444
# 27              Nebraska   1869365       763796      136799         65156
# 28                Nevada   2798636      1046115      156402         64300
# 29         New Hampshire   1324201       555075       94291         48690
# 30            New Jersey   8904413      3480774      593056        202379
# 31            New Mexico   2084117       621466      193899         58437
# 32              New York  19673174      7253289     1444775        546106
# 33        North Carolina   9845333      3461237      652446        252891
# 34          North Dakota    721640       291445       63548         31524
# 35                  Ohio  11575977      4418761      672901        267339
# 36              Oklahoma   3849733      1316723      291424        107445
# 37                Oregon   3939233      1395458      252410        138975
# 38          Pennsylvania  12779559      5035025      649482        308795
# 39           Puerto Rico   3583073       721261      243577         96887
# 40          Rhode Island   1053661       426692       65733         25472
# 41        South Carolina   4777576      1634236      327594        110395
# 42          South Dakota    843190       327422       66667         35556
# 43             Tennessee   6499615      2281151      405128        197918
# 44                 Texas  26538614      9602271     1673138        799113
# 45                  Utah   2903379      1070395      204272         60790
# 46               Vermont    626604       248074       47671         30237
# 47              Virginia   8256630      2970487      815683        199017
# 48            Washington   6985464      2530615      527312        195935
# 49         West Virginia   1851420       574140      142824         33299
# 50             Wisconsin   5742117      2372410      357136        148212
# 51               Wyoming    579679       212611       61881         18714
#
#     FamilyWork
# 0         3715
# 1          634
# 2         5502
# 3         2406
# 4        34099
# 5         5037
# 6         2991
# 7          583
# 8          337
# 9        12947
# 10        7422
# 11        1224
# 12        1931
# 13        8370
# 14        4649
# 15        3400
# 16        2608
# 17        2957
# 18        2594
# 19         963
# 20        3696
# 21        4306
# 22        7173
# 23        4298
# 24        1658
# 25        5226
# 26        2339
# 27        1837
# 28        1375
# 29         747
# 30        5794
# 31        1745
# 32       11432
# 33        7194
# 34        1157
# 35        7492
# 36        3778
# 37        2778
# 38        8607
# 39        1729
# 40         590
# 41        3100
# 42        1131
# 43        4474
# 44       17558
# 45        1977
# 46         718
# 47        4623
# 48        6021
# 49         806
# 50        5092
# 51         684

# %%
# Creating a 'Stacked Bar Graph' for 2015 to display the ratios of workforce sectors:
x = sectors_2015['State']
y0 = sectors_2015['FamilyWork']
y1 = sectors_2015['SelfEmployed']
y2 = sectors_2015['PrivateWork']
y3 = sectors_2015['PublicWork']

plt.figure(figsize=(15, 15))

p1 = plt.bar(x,y0, color='blue', label='FamilyWork')
p2 = plt.bar(x,y1, color='green', label='SelfEmployed')
p3 = plt.bar(x,y2, color='red', label='PrivateWork')
p4 = plt.bar(x,y3, color='orange', label='PublicWork')


plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(y2)+1000000)

plt.title("Workforce Sectors based on 2015 Total State Population")
plt.xlabel("U.S. States, DC, & Puerto Rico")
plt.ylabel("Total Population per State")
plt.legend(loc='best')

tick_locations = [value for value in x]
plt.xticks(tick_locations, rotation=90)

plt.savefig('Images/Fig3.png')
plt.show()

# %%
# Building a dataframe to find the workforce sectors that make-up the states based on 2017:
sectors_2017 = states_2017[['State', 'TotalPop', 'PrivateWork', 'PublicWork', 'SelfEmployed', 'FamilyWork']]
sectors_2017
# Out:
#                    State  TotalPop  PrivateWork  PublicWork  SelfEmployed  \
# 0                Alabama   4850771      1624514      320525        106343
# 1                 Alaska    738565       241717       89250         22129
# 2                Arizona   6809946      2357823      411571        178504
# 3               Arkansas   2977944       997809      198806         77564
# 4             California  38982847     14065256     2429116       1465746
# 5               Colorado   5436519      2209392      371345        174156
# 6            Connecticut   3594478      1452157      234496        115009
# 7               Delaware    943732       361061       62725         17203
# 8   District of Columbia    672391       253967       87994         15381
# 9                Florida  20278447      7401784     1069670        532536
# 10               Georgia  10201635      3668361      677406        253455
# 11                Hawaii   1421658       487621      136834         45699
# 12                 Idaho   1657375       579003      113082         54638
# 13              Illinois  12854526      5149540      736506        287016
# 14               Indiana   6614418      2644709      333289        141229
# 15                  Iowa   3118102      1282007      212438        102307
# 16                Kansas   2903820      1111567      220185         85382
# 17              Kentucky   4424376      1552313      279185        102945
# 18             Louisiana   4663461      1611895      302257        113840
# 19                 Maine   1330158       511443       89818         56658
# 20              Maryland   5996079      2227087      664420        145507
# 21         Massachusetts   6789319      2886800      427505        205361
# 22              Michigan   9925568      3816198      477220        224002
# 23             Minnesota   5490726      2403938      338533        156259
# 24           Mississippi   2986220       931526      220984         67165
# 25              Missouri   6075300      2352563      349298        159305
# 26               Montana   1029862       364853       87281         43854
# 27              Nebraska   1893921       788209      135887         61305
# 28                Nevada   2887725      1110821      160365         68691
# 29         New Hampshire   1331848       571424       94351         46779
# 30            New Jersey   8960161      3588935      589068        203227
# 31            New Mexico   2084828       625124      194248         57894
# 32              New York  19798228      7452696     1449290        553033
# 33        North Carolina  10052564      3641770      659822        262385
# 34          North Dakota    745475       305999       62691         30494
# 35                  Ohio  11609756      4553734      661459        266141
# 36              Oklahoma   3896251      1342974      291785        107479
# 37                Oregon   4025127      1484420      257638        140748
# 38          Pennsylvania  12790505      5143504      633484        310586
# 39           Puerto Rico   3468963       713424      228951         96165
# 40          Rhode Island   1056138       434723       64403         26457
# 41        South Carolina   4893444      1732808      331106        113904
# 42          South Dakota    855444       336241       65201         35527
# 43             Tennessee   6597381      2378964      408829        203141
# 44                 Texas  27419612     10148892     1674416        844242
# 45                  Utah   2993941      1139536      204783         65814
# 46               Vermont    624636       251433       46317         28693
# 47              Virginia   8365952      3058148      820049        200152
# 48            Washington   7169967      2668142      543336        199857
# 49         West Virginia   1836843       572968      139949         32973
# 50             Wisconsin   5763217      2425502      358891        150187
# 51               Wyoming    583200       212774       61389         18524
#
#     FamilyWork
# 0         3905
# 1          709
# 2         3943
# 3         2215
# 4        33582
# 5         5128
# 6         2829
# 7          519
# 8          357
# 9        13542
# 10        7274
# 11        1091
# 12        1957
# 13        8884
# 14        4329
# 15        2887
# 16        2475
# 17        3334
# 18        2907
# 19         716
# 20        3606
# 21        4593
# 22        7994
# 23        4303
# 24        1932
# 25        5255
# 26        1938
# 27        1729
# 28        1448
# 29         700
# 30        6410
# 31        1858
# 32       13406
# 33        6716
# 34        1102
# 35        7594
# 36        3604
# 37        3554
# 38        8806
# 39        1579
# 40         590
# 41        3499
# 42        1358
# 43        4907
# 44       21634
# 45        2071
# 46         790
# 47        5636
# 48        6431
# 49         844
# 50        5241
# 51         901

# %%
# Creating a 'Stacked Bar Graph' for 2017 to display the ratios of workforce sectors:
x = sectors_2017['State']
y0 = sectors_2017['FamilyWork']
y1 = sectors_2017['SelfEmployed']
y2 = sectors_2017['PrivateWork']
y3 = sectors_2017['PublicWork']

plt.figure(figsize=(15, 15))

p1 = plt.bar(x,y0, color='blue', label='FamilyWork')
p2 = plt.bar(x,y1, color='green', label='SelfEmployed')
p3 = plt.bar(x,y2, color='red', label='PrivateWork')
p4 = plt.bar(x,y3, color='orange', label='PublicWork')


plt.xlim(-0.75, len(x)-0.25)
plt.ylim(0, max(y2)+1000000)

plt.title("Workforce Sectors based on 2017 Total State Population")
plt.xlabel("U.S. States, DC, & Puerto Rico")
plt.ylabel("Total Population per State")
plt.legend(loc='best')

tick_locations = [value for value in x]
plt.xticks(tick_locations, rotation=90)

plt.savefig('Images/Fig4.png')
plt.show()
